# %%
import pandas as p

# %%
data = pd.read_csv("https://raw.githubusercontent.com/joanby/python-ml-course/master/datasets/customer-churn-model/Customer%20Churn%20Model.txt")
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 0                25     265.1        110       45.07  ...         99
# 1                26     161.6        123       27.47  ...        103
# 2                 0     243.4        114       41.38  ...        110
# 3                 0     299.4         71       50.90  ...         88
# 4                 0     166.7        113       28.34  ...        122
# ...             ...       ...        ...         ...  ...        ...
# 3328             36     156.2         77       26.55  ...        126
# 3329              0     231.1         57       39.29  ...         55
# 3330              0     180.8        109       30.74  ...         58
# 3331              0     213.8        105       36.35  ...         84
# 3332             25     234.4        113       39.85  ...         82
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 0          16.78       244.7           91         11.01       10.0
# 1          16.62       254.4          103         11.45       13.7
# 2          10.30       162.6          104          7.32       12.2
# 3           5.26       196.9           89          8.86        6.6
# 4          12.61       186.9          121          8.41       10.1
# ...          ...         ...          ...           ...        ...
# 3328       18.32       279.1           83         12.56        9.9
# 3329       13.04       191.3          123          8.61        9.6
# 3330       24.55       191.9           91          8.64       14.1
# 3331       13.57       139.2          137          6.26        5.0
# 3332       22.60       241.4           77         10.86       13.7
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0              3         2.70               1  False.
# 1              3         3.70               1  False.
# 2              5         3.29               0  False.
# 3              7         1.78               2  False.
# 4              3         2.73               3  False.
# ...          ...          ...             ...     ...
# 3328           6         2.67               2  False.
# 3329           4         2.59               3  False.
# 3330           6         3.81               2  False.
# 3331          10         1.35               2  False.
# 3332           4         3.70               0  False.
#
# [3333 rows x 21 columns]

# %%
accLen = data["State"]
data.plot(alpha=.4)
# Out:
# <AxesSubplot:>

# %%
#We select  the data that we need
wantedCols = ["Account Length","Phone","Eve Charge","Day Calls"]

# %%
wantedCols
# Out:
# ['Account Length', 'Phone', 'Eve Charge', 'Day Calls']

# %%
allColumnsList = data.columns.values.tolist()
allColumnsList
# Out:
# ['State',
#  'Area Code',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
#Loop for choosing the complementary
subList = [x for x in allColumnsList if x not in wantedCols ]

# %%
subListe = [x for x in allColumnsList if x not in wantedCols ]

# %%
data1 = data[subList]

# %%
data1
# Out:
#      State  Area Code Int'l Plan VMail Plan  VMail Message  Day Mins  \
# 0       KS        415         no        yes             25     265.1
# 1       OH        415         no        yes             26     161.6
# 2       NJ        415         no         no              0     243.4
# 3       OH        408        yes         no              0     299.4
# 4       OK        415        yes         no              0     166.7
# ...    ...        ...        ...        ...            ...       ...
# 3328    AZ        415         no        yes             36     156.2
# 3329    WV        415         no         no              0     231.1
# 3330    RI        510         no         no              0     180.8
# 3331    CT        510        yes         no              0     213.8
# 3332    TN        415         no        yes             25     234.4
#
#       Day Charge  Eve Mins  Eve Calls  Night Mins  Night Calls  Night Charge  \
# 0          45.07     197.4         99       244.7           91         11.01
# 1          27.47     195.5        103       254.4          103         11.45
# 2          41.38     121.2        110       162.6          104          7.32
# 3          50.90      61.9         88       196.9           89          8.86
# 4          28.34     148.3        122       186.9          121          8.41
# ...          ...       ...        ...         ...          ...           ...
# 3328       26.55     215.5        126       279.1           83         12.56
# 3329       39.29     153.4         55       191.3          123          8.61
# 3330       30.74     288.8         58       191.9           91          8.64
# 3331       36.35     159.6         84       139.2          137          6.26
# 3332       39.85     265.9         82       241.4           77         10.86
#
#       Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0          10.0           3         2.70               1  False.
# 1          13.7           3         3.70               1  False.
# 2          12.2           5         3.29               0  False.
# 3           6.6           7         1.78               2  False.
# 4          10.1           3         2.73               3  False.
# ...         ...         ...          ...             ...     ...
# 3328        9.9           6         2.67               2  False.
# 3329        9.6           4         2.59               3  False.
# 3330       14.1           6         3.81               2  False.
# 3331        5.0          10         1.35               2  False.
# 3332       13.7           4         3.70               0  False.
#
# [3333 rows x 17 columns]

# %%
# alternatively
# a = set(desired_columns)
# b = set(all_columns_list)
# sublist = b-a
# sublist = list(sublist)

# %%
#Get the first 25 rows!!
data[1:10] #==data[:10]
# Out:
#   State  Area Code Int'l Plan VMail Plan  VMail Message  Day Mins  Day Charge  \
# 1    OH        415         no        yes             26     161.6       27.47
# 2    NJ        415         no         no              0     243.4       41.38
# 3    OH        408        yes         no              0     299.4       50.90
# 4    OK        415        yes         no              0     166.7       28.34
# 5    AL        510        yes         no              0     223.4       37.98
# 6    MA        510         no        yes             24     218.2       37.09
# 7    MO        415        yes         no              0     157.0       26.69
# 8    LA        408         no         no              0     184.5       31.37
# 9    WV        415        yes        yes             37     258.6       43.96
#
#    Eve Mins  Eve Calls  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 1     195.5        103       254.4          103         11.45       13.7
# 2     121.2        110       162.6          104          7.32       12.2
# 3      61.9         88       196.9           89          8.86        6.6
# 4     148.3        122       186.9          121          8.41       10.1
# 5     220.6        101       203.9          118          9.18        6.3
# 6     348.5        108       212.6          118          9.57        7.5
# 7     103.1         94       211.8           96          9.53        7.1
# 8     351.6         80       215.8           90          9.71        8.7
# 9     222.0        111       326.4           97         14.69       11.2
#
#    Intl Calls  Intl Charge  CustServ Calls  Churn?
# 1           3         3.70               1  False.
# 2           5         3.29               0  False.
# 3           7         1.78               2  False.
# 4           3         2.73               3  False.
# 5           6         1.70               0  False.
# 6           7         2.03               3  False.
# 7           6         1.92               0  False.
# 8           4         2.35               1  False.
# 9           5         3.02               0  False.

# %%
#we filter the ones bigger than 
dataB = data[data["Day Charge"]>25]
dataB
# Out:
#      State  Area Code Int'l Plan VMail Plan  VMail Message  Day Mins  \
# 0       KS        415         no        yes             25     265.1
# 1       OH        415         no        yes             26     161.6
# 2       NJ        415         no         no              0     243.4
# 3       OH        408        yes         no              0     299.4
# 4       OK        415        yes         no              0     166.7
# ...    ...        ...        ...        ...            ...       ...
# 3328    AZ        415         no        yes             36     156.2
# 3329    WV        415         no         no              0     231.1
# 3330    RI        510         no         no              0     180.8
# 3331    CT        510        yes         no              0     213.8
# 3332    TN        415         no        yes             25     234.4
#
#       Day Charge  Eve Mins  Eve Calls  Night Mins  Night Calls  Night Charge  \
# 0          45.07     197.4         99       244.7           91         11.01
# 1          27.47     195.5        103       254.4          103         11.45
# 2          41.38     121.2        110       162.6          104          7.32
# 3          50.90      61.9         88       196.9           89          8.86
# 4          28.34     148.3        122       186.9          121          8.41
# ...          ...       ...        ...         ...          ...           ...
# 3328       26.55     215.5        126       279.1           83         12.56
# 3329       39.29     153.4         55       191.3          123          8.61
# 3330       30.74     288.8         58       191.9           91          8.64
# 3331       36.35     159.6         84       139.2          137          6.26
# 3332       39.85     265.9         82       241.4           77         10.86
#
#       Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0          10.0           3         2.70               1  False.
# 1          13.7           3         3.70               1  False.
# 2          12.2           5         3.29               0  False.
# 3           6.6           7         1.78               2  False.
# 4          10.1           3         2.73               3  False.
# ...         ...         ...          ...             ...     ...
# 3328        9.9           6         2.67               2  False.
# 3329        9.6           4         2.59               3  False.
# 3330       14.1           6         3.81               2  False.
# 3331        5.0          10         1.35               2  False.
# 3332       13.7           4         3.70               0  False.
#
# [2422 rows x 17 columns]

# %%
nyUser = data[(data["State"]=="NY") | (data["Eve Mins"]>10.0)]
nyUser.shape
# Out:
# (3332, 17)

# %%
#tecnica ancestral
subsetFirst50 = data[["Day Mins","Night Mins","State"]][:50]
subsetFirst50.shape
# Out:
# (50, 3)

# %%
#check indexes: files i cols
data.iloc[:10, 3:6]
data.iloc[:, 3:6] #totes fils
data.iloc[:10, :] #totes cols
# Out:
#   VMail Plan  VMail Message  Day Mins
# 0        yes             25     265.1
# 1        yes             26     161.6
# 2         no              0     243.4
# 3         no              0     299.4
# 4         no              0     166.7
# 5         no              0     223.4
# 6        yes             24     218.2
# 7         no              0     157.0
# 8         no              0     184.5
# 9        yes             37     258.6
